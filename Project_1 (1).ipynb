# %%
import pandas as pd
from pathlib import Path
import hvplot.pandas
from matplotlib import pyplot as plt
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
load_unemployment_data = Path("Resources/unemployment_data.csv")
unemployment_data = pd.read_csv(load_unemployment_data)
unemployment_data
# Out:
#    YEAR  Number of Unemployed
# 0  2014               9262000
# 1  2015               9090000
# 2  2016               7652000
# 3  2017               7082000
# 4  2018               6481000
# 5  2019               5941000
# 6  2020              17624000
# 7  2021               9982000

# %%
load_heart_data = Path("Resources/heart_data.csv")
heart_data = pd.read_csv(load_heart_data)
heart_data.head()
# Out:
#    YEAR STATE   RATE  DEATHS
# 0  2021    AL  247.5   15173
# 1  2021    AK  154.7    1011
# 2  2021    AZ  158.3   14550
# 3  2021    AR  231.0    8547
# 4  2021    CA  147.8   65471

# %%
heart_data = heart_data.drop(columns=["RATE","STATE",])
heart_data.head()
# Out:
#    YEAR  DEATHS
# 0  2021   15173
# 1  2021    1011
# 2  2021   14550
# 3  2021    8547
# 4  2021   65471

# %%
death_totals = heart_data.groupby(["YEAR"]).sum()
death_totals
# Out:
#       DEATHS
# YEAR
# 2014  613024
# 2015  632625
# 2016  633885
# 2017  646173
# 2018  654086
# 2019  657854
# 2020  695612
# 2021  694259

# %%
heart_y_axis = death_totals["DEATHS"]
heart_y_axis
# Out:
# YEAR
# 2014    613024
# 2015    632625
# 2016    633885
# 2017    646173
# 2018    654086
# 2019    657854
# 2020    695612
# 2021    694259
# Name: DEATHS, dtype: int64

# %%
heart_x_axis = heart_data.groupby(["YEAR"])
heart_x_axis.groups.keys()
# Out:
# dict_keys([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
plt.plot(heart_x_axis.groups.keys(), heart_y_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
unemployment_x_axis =unemployment_data["YEAR"]
unemployment_y_axis =unemployment_data["Number of Unemployed"]

# %%
plt.plot(unemployment_x_axis, unemployment_y_axis)
plt.xticks(rotation=90)
plt.xlabel("YEAR")
plt.ylabel("NUMBER OF PEOPLE")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(unemployment_x_axis, unemployment_y_axis)
plt.plot(heart_x_axis.groups.keys(), heart_y_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_ylabel("Number of Unemployed", color = color)
ax1.plot(unemployment_x_axis, unemployment_y_axis, color = color)
ax1.tick_params(axis='y', labelcolor=color)
color = 'tab:blue'
ax2 = ax1.twinx()
ax2.set_ylabel('Number of Heart Disease Deaths', color = color)
ax2.plot(unemployment_x_axis, heart_y_axis, color = color)
ax2.tick_params(axis = 'y', labelcolor = color)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
